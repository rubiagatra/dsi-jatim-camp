# %% [markdown]
# # Pandas read csv

# %%
import pandas as pd

# %%
# Kamu bisa membaca format csv dengan fungsi read_csv() pada pandas
kriminal = pd.read_csv('crime_rates.csv')
kriminal
# Out:
#               Albuquerque   749
# 0                 Anaheim   371
# 1               Anchorage   828
# 2               Arlington   503
# 3                 Atlanta  1379
# 4                  Aurora   425
# 5                  Austin   408
# 6             Bakersfield   542
# 7               Baltimore  1405
# 8                  Boston   835
# 9                 Buffalo  1288
# 10  Charlotte-Mecklenburg   647
# 11             Cincinnati   974
# 12              Cleveland  1383
# 13       Colorado Springs   455
# 14         Corpus Christi   658
# 15                 Dallas   675
# 16                 Denver   615
# 17                Detroit  2122
# 18                El Paso   423
# 19             Fort Wayne   362
# 20             Fort Worth   587
# 21                 Fresno   543
# 22             Greensboro   563
# 23              Henderson   168
# 24                Houston   992
# 25           Indianapolis  1185
# 26           Jacksonville   617
# 27            Jersey City   734
# ...

# %%
# Tugas 1

# Gunakan fungsi read_csv untuk membaca food_info.csv yang telah disediakan ke dalam info_makanan

# %% [markdown]
# # Exploring The DataFrame

# %%
# Kita gunakan fungsi head() untuk menampilka 5 baris pertama
info_makanan.head()
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 3    1004             CHEESE,BLUE      42.41         353        21.40
# 4    1005            CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 3          28.74     5.11            2.34           0.0           0.50
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Lycopene_(µg)  Lut+Zea_ (µg)  Vit_E_(mg)  Vit_D_µg  \
# ...

# %%
# Denga menambahkan parameter integer pada head() maka hasilnya akan seperti ini
info_makanan.head(3)
# Out:
#    NDB_No               Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001        BUTTER,WITH SALT      15.87         717         0.85
# 1    1002  BUTTER,WHIPPED,W/ SALT      16.72         718         0.49
# 2    1003    BUTTER OIL,ANHYDROUS       0.24         876         0.28
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 1          78.30     1.62            2.87           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
#
#         ...        Lycopene_(µg)  Lut+Zea_ (µg)  Vit_E_(mg)  Vit_D_µg  \
# 0       ...                  0.0            0.0        2.32       0.0
# 1       ...                  0.0           13.0        1.37       0.0
# 2       ...                  0.0            0.0        2.80       0.0
#
#    Vit_D_IU  Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
# Kamu bisa menampilkan kolom apa saja dalam DataFrame
kolom_makanan = info_makanan.columns
kolom_makanan
# Out:
# Index(['NDB_No', 'Shrt_Desc', 'Water_(g)', 'Energ_Kcal', 'Protein_(g)',
#        'Lipid_Tot_(g)', 'Ash_(g)', 'Carbohydrt_(g)', 'Fiber_TD_(g)',
#        'Sugar_Tot_(g)', 'Calcium_(mg)', 'Iron_(mg)', 'Magnesium_(mg)',
#        'Phosphorus_(mg)', 'Potassium_(mg)', 'Sodium_(mg)', 'Zinc_(mg)',
#        'Copper_(mg)', 'Manganese_(mg)', 'Selenium_(µg)', 'Vit_C_(mg)',
#        'Thiamin_(mg)', 'Riboflavin_(mg)', 'Niacin_(mg)', 'Panto_Acid_mg)',
#        'Vit_B6_(mg)', 'Folate_Tot_(µg)', 'Folic_Acid_(µg)', 'Food_Folate_(µg)',
#        'Folate_DFE_(µg)', 'Choline_Tot_ (mg)', 'Vit_B12_(µg)', 'Vit_A_IU',
#        'Vit_A_RAE', 'Retinol_(µg)', 'Alpha_Carot_(µg)', 'Beta_Carot_(µg)',
#        'Beta_Crypt_(µg)', 'Lycopene_(µg)', 'Lut+Zea_ (µg)', 'Vit_E_(mg)',
#        'Vit_D_µg', 'Vit_D_IU', 'Vit_K_(µg)', 'FA_Sat_(g)', 'FA_Mono_(g)',
#        'FA_Poly_(g)', 'Cholestrl_(mg)'],
#       dtype='object')

# %%
# Kamu bisa menampilkan bentuk dari sebuah data dalam DataFrame
bentuk_data_makanan = info_makanan.shape
bentuk_data_makanan
# Out:
# (8790, 48)

# %%
# Tugas 2

# Tampilkan 20 baris pertama pada info_makanan ke dalam dua_puluh_pertama

# %% [markdown]
# # Series and selecting row

# %%
# Kita dapat mengambil sebuah baris pada DataFrame
# Baris ini merupakan bentuk struktur data dari Pandas yang bernama Series

info_makanan.loc[0]
# Out:
# NDB_No                           1001
# Shrt_Desc            BUTTER,WITH SALT
# Water_(g)                       15.87
# Energ_Kcal                        717
# Protein_(g)                      0.85
# Lipid_Tot_(g)                   81.11
# Ash_(g)                          2.11
# Carbohydrt_(g)                   0.06
# Fiber_TD_(g)                        0
# Sugar_Tot_(g)                    0.06
# Calcium_(mg)                       24
# Iron_(mg)                        0.02
# Magnesium_(mg)                      2
# Phosphorus_(mg)                    24
# Potassium_(mg)                     24
# Sodium_(mg)                       643
# Zinc_(mg)                        0.09
# Copper_(mg)                         0
# Manganese_(mg)                      0
# Selenium_(µg)                       1
# Vit_C_(mg)                          0
# Thiamin_(mg)                    0.005
# Riboflavin_(mg)                 0.034
# Niacin_(mg)                     0.042
# Panto_Acid_mg)                   0.11
# ...

# %%
info_makanan.loc[2]
# Out:
# NDB_No                               1003
# Shrt_Desc            BUTTER OIL,ANHYDROUS
# Water_(g)                            0.24
# Energ_Kcal                            876
# Protein_(g)                          0.28
# Lipid_Tot_(g)                       99.48
# Ash_(g)                                 0
# Carbohydrt_(g)                          0
# Fiber_TD_(g)                            0
# Sugar_Tot_(g)                           0
# Calcium_(mg)                            4
# Iron_(mg)                               0
# Magnesium_(mg)                          0
# Phosphorus_(mg)                         3
# Potassium_(mg)                          5
# Sodium_(mg)                             2
# Zinc_(mg)                            0.01
# Copper_(mg)                         0.001
# Manganese_(mg)                          0
# Selenium_(µg)                           0
# Vit_C_(mg)                              0
# Thiamin_(mg)                        0.001
# ...

# %%
# Error karena diluar index
info_makanan.loc[8790]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [8790] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-763beaaa23c9> in <module>()
#       1 # Error karena diluar index
# ----> 2 info_makanan.loc[8790]
#
# ...

# %%
# Tugas 3

# Masukkan baris ke 100 info_makanan ke dalam baris_seratus

# %% [markdown]
# # Data Types

# %%
# Kamu bisa melihat semua tipe data pada DataFrame
info_makanan.dtypes
# Out:
# NDB_No                 int64
# Shrt_Desc             object
# Water_(g)            float64
# Energ_Kcal             int64
# Protein_(g)          float64
# Lipid_Tot_(g)        float64
# Ash_(g)              float64
# Carbohydrt_(g)       float64
# Fiber_TD_(g)         float64
# Sugar_Tot_(g)        float64
# Calcium_(mg)         float64
# Iron_(mg)            float64
# Magnesium_(mg)       float64
# Phosphorus_(mg)      float64
# Potassium_(mg)       float64
# Sodium_(mg)          float64
# Zinc_(mg)            float64
# Copper_(mg)          float64
# Manganese_(mg)       float64
# Selenium_(µg)        float64
# Vit_C_(mg)           float64
# Thiamin_(mg)         float64
# Riboflavin_(mg)      float64
# Niacin_(mg)          float64
# Panto_Acid_mg)       float64
# Vit_B6_(mg)          float64
# Folate_Tot_(µg)      float64
# Folic_Acid_(µg)      float64
# Food_Folate_(µg)     float64
# Folate_DFE_(µg)      float64
# Choline_Tot_ (mg)    float64
# Vit_B12_(µg)         float64
# ...

# %% [markdown]
# # Selecting multiple rows

# %%
# Kita dapat menampilkan baris lebih dari satu
info_makanan.loc[3:5]
# Out:
#    NDB_No     Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# 3    1004   CHEESE,BLUE      42.41         353        21.40          28.74
# 4    1005  CHEESE,BRICK      41.11         371        23.24          29.68
# 5    1006   CHEESE,BRIE      48.42         334        20.75          27.68
#
#    Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)       ...        \
# 3     5.11            2.34           0.0           0.50       ...
# 4     3.18            2.79           0.0           0.51       ...
# 5     2.70            0.45           0.0           0.45       ...
#
#    Lycopene_(µg)  Lut+Zea_ (µg)  Vit_E_(mg)  Vit_D_µg  Vit_D_IU  Vit_K_(µg)  \
# 3            0.0            0.0        0.25       0.5      21.0         2.4
# 4            0.0            0.0        0.26       0.5      22.0         2.5
# 5            0.0            0.0        0.24       0.5      20.0         2.3
#
#    FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
info_makanan.loc[[0,2,4]]
# Out:
#    NDB_No             Shrt_Desc  Water_(g)  Energ_Kcal  Protein_(g)  \
# 0    1001      BUTTER,WITH SALT      15.87         717         0.85
# 2    1003  BUTTER OIL,ANHYDROUS       0.24         876         0.28
# 4    1005          CHEESE,BRICK      41.11         371        23.24
#
#    Lipid_Tot_(g)  Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  \
# 0          81.11     2.11            0.06           0.0           0.06
# 2          99.48     0.00            0.00           0.0           0.00
# 4          29.68     3.18            2.79           0.0           0.51
#
#         ...        Lycopene_(µg)  Lut+Zea_ (µg)  Vit_E_(mg)  Vit_D_µg  \
# 0       ...                  0.0            0.0        2.32       0.0
# 2       ...                  0.0            0.0        2.80       0.0
# 4       ...                  0.0            0.0        0.26       0.5
#
#    Vit_D_IU  Vit_K_(µg)  FA_Sat_(g)  FA_Mono_(g)  FA_Poly_(g)  Cholestrl_(mg)
# ...

# %%
# Tugas 3

# Tampilkan 5 baris terakhir info_makanan pada lima_baris_terakhir

# %% [markdown]
# # Selecting Individual Columns

# %%
# Kamu bisa menampilkan sebuah kolom berdasarkan nama dari kolom tersebut

kolom_nbd = info_makanan['NDB_No']
kolom_nbd
# Out:
# 0        1001
# 1        1002
# 2        1003
# 3        1004
# 4        1005
# 5        1006
# 6        1007
# 7        1008
# 8        1009
# 9        1010
# 10       1011
# 11       1012
# 12       1013
# 13       1014
# 14       1015
# 15       1016
# 16       1017
# 17       1018
# 18       1019
# 19       1020
# 20       1021
# 21       1022
# 22       1023
# 23       1024
# 24       1025
# 25       1026
# 26       1027
# 27       1028
# 28       1029
# 29       1030
#         ...
# 8760    43544
# 8761    43546
# 8762    43550
# 8763    43566
# 8764    43570
# 8765    43572
# 8766    43585
# 8767    43589
# 8768    43595
# 8769    43597
# 8770    43598
# 8771    44005
# 8772    44018
# 8773    44048
# 8774    44055
# 8775    44061
# 8776    44074
# 8777    44110
# 8778    44158
# 8779    44203
# 8780    44258
# 8781    44259
# 8782    44260
# 8783    48052
# 8784    80200
# 8785    83110
# 8786    90240
# 8787    90480
# 8788    90560
# 8789    93600
# ...

# %%
# Tugas 4

# 1. Tampilkan "FA_Sat_(g)" pada lemak_jenuh
# 2  Tampilkan "Cholestrl_(mg)" pada kolesterol

# %% [markdown]
# # Selecting multiple columns by name

# %%
# Kamu bisa memilih dua kolom dalam waktu yang bersamaan

kalsium_perunggu = info_makanan[["Zinc_(mg)", "Copper_(mg)"]]
kalsium_perunggu
# Out:
#       Zinc_(mg)  Copper_(mg)
# 0          0.09        0.000
# 1          0.05        0.010
# 2          0.01        0.001
# 3          2.66        0.040
# 4          2.60        0.024
# 5          2.38        0.019
# 6          2.38        0.021
# 7          2.94        0.024
# 8          3.64        0.030
# 9          2.79        0.042
# 10         3.07        0.042
# 11         0.40        0.029
# 12         0.33        0.040
# 13         0.47        0.030
# 14         0.51        0.033
# 15         0.38        0.028
# 16         0.50        0.018
# 17         3.75        0.036
# 18         2.88        0.032
# 19         3.50        0.025
# 20         1.14        0.080
# 21         3.90        0.036
# 22         3.90        0.032
# 23         2.10        0.021
# 24         3.00        0.032
# 25         2.92        0.011
# 26         2.46        0.022
# 27         2.76        0.025
# 28         3.62        0.033
# 29         2.81        0.031
# ...         ...          ...
# ...

# %%
# Tugas 5

# 1. Masukkan  'Selenium_(mcg)' dan 'Thiamin_(mg)'dalam selenium_thiamin

# %% [markdown]
# ## Summarizing and Computing Descriptive Statistics

# %%
info_makanan.sum()
# Out:
# NDB_No                                                       137682123
# Shrt_Desc            BUTTER,WITH SALTBUTTER,WHIPPED,W/ SALTBUTTER O...
# Water_(g)                                                       475592
# Energ_Kcal                                                     1989332
# Protein_(g)                                                    99703.6
# Lipid_Tot_(g)                                                  92767.2
# Ash_(g)                                                        15097.1
# Carbohydrt_(g)                                                  194503
# Fiber_TD_(g)                                                   17928.3
# Sugar_Tot_(g)                                                  59442.7
# Calcium_(mg)                                                    647824
# Iron_(mg)                                                      23341.4
# Magnesium_(mg)                                                  284168
# ...

# %%
info_makanan.mean()
# Out:
# NDB_No               15663.495222
# Water_(g)               54.112218
# Energ_Kcal             226.317634
# Protein_(g)             11.342849
# Lipid_Tot_(g)           10.553725
# Ash_(g)                  1.783468
# Carbohydrt_(g)          22.127710
# Fiber_TD_(g)             2.187445
# Sugar_Tot_(g)            8.543066
# Calcium_(mg)            76.738214
# Iron_(mg)                2.699674
# Magnesium_(mg)          35.295988
# Phosphorus_(mg)        165.142126
# Potassium_(mg)         279.472740
# Sodium_(mg)            312.495923
# Zinc_(mg)                2.117438
# Copper_(mg)              0.195984
# Manganese_(mg)           0.658156
# Selenium_(µg)           15.591016
# Vit_C_(mg)               9.231134
# Thiamin_(mg)             0.223134
# Riboflavin_(mg)          0.252237
# Niacin_(mg)              3.657721
# Panto_Acid_mg)           0.650989
# Vit_B6_(mg)              0.291531
# Folate_Tot_(µg)         51.598220
# Folic_Acid_(µg)         23.169012
# ...

# %%
info_makanan.describe()
# Out:
#              NDB_No    Water_(g)   Energ_Kcal  Protein_(g)  Lipid_Tot_(g)  \
# count   8790.000000  8789.000000  8790.000000  8790.000000    8790.000000
# mean   15663.495222    54.112218   226.317634    11.342849      10.553725
# std     9251.413586    30.772854   169.877539    10.530474      15.814842
# min     1001.000000     0.000000     0.000000     0.000000       0.000000
# 25%     9086.250000    29.700000    91.000000     2.380000       0.950000
# 50%    14427.500000    63.080000   191.000000     8.000000       5.140000
# 75%    20142.750000    77.960000   337.000000    19.880000      13.720000
# max    93600.000000   100.000000   902.000000    88.320000     100.000000
#
#            Ash_(g)  Carbohydrt_(g)  Fiber_TD_(g)  Sugar_Tot_(g)  Calcium_(mg)  \
# count  8465.000000     8790.000000   8196.000000    6958.000000   8442.000000
# mean      1.783468       22.127710      2.187445       8.543066     76.738214
# ...
